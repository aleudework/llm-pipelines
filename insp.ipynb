# %%
import pandas as pd

path = '/Users/alhu/VSC/llm-pipelines/backup/afdelingstekster_ja_nej/backup.parquet'

df = pd.read_parquet(path)

out = '/Users/alhu/Downloads/afdelingsklausuler_test.xlsx'

df.to_excel(out, index=False)
